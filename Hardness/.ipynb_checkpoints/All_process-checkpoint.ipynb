# %%
import pathlib 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import concatenate
from tensorflow.keras.models import Model
from sklearn.model_selection import KFold
from tensorflow.keras.utils import plot_model
import eli5
from eli5.sklearn import PermutationImportance
tf.compat.v1.disable_eager_execution()

def norm(x):     
    return (x-min)/(max-min)

def r2(inp,pred):
    Minp= np.mean(inp)
    Mpred=np.mean(pred)
    
    temp1=inp-Minp
    temp2=pred-Mpred

    temp3= temp1**2
    temp4=temp2**2

    temp5=np.sqrt(np.sum(temp3))
    temp6=np.sqrt(np.sum(temp4))

    temp7= np.sum(temp1*temp2)
    temp8=temp5*temp6
    cor=temp7/temp8
    return cor**2 

def mae(inp,pred):
    temp1= np.abs(inp-pred)
    temp1=np.mean(temp1)

    return temp1

def rmse(inp,pred):
    temp1= (inp-pred)**2
    temp1=np.mean(temp1)
    temp1=np.sqrt(temp1)
    return temp1

        

# get dataset from csv file 
folder_path='Training\\'
if os.path.exists(folder_path)==False:
    os.mkdir(folder_path)
data_path='training.csv'
test_path='test.csv'

max=[1000,20,35,2000,80000,150,100]
max=np.array(max)
min=[0,0,0,0,0,0,0]
min=np.array(min)
#normalization


column_names=['Yield Strengh','UTS','Cr %','Depth','Strikes/mm2','Static Force','Amplitude','Hardness']
column_names_r=['Yield Strengh','UTS','Cr %','Depth','Strikes/mm2','Static Force','Amplitude']
raw_dataset =pd.read_csv(data_path,names=column_names, skipinitialspace=True)
raw_dataset2=pd.read_csv(test_path,names=column_names, skipinitialspace=True)
train_dataset=raw_dataset.copy()
test_dataset=raw_dataset2.copy()
x_column=train_dataset.columns.drop('Hardness')
x=norm(train_dataset[x_column].values)
y=train_dataset['Hardness'].values

x_val=norm(test_dataset[x_column].values)
y_val=test_dataset['Hardness'].values
# Out:
# C:\Users\janpo\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\janpo\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # This part is for the training process:

# %%
def build_model(n1,n2):
    inputL = Input(shape=(7,))

        
    z=Dense(n1,activation="relu")(inputL)
    z=Dense(n2,activation="relu")(z)
    z=Dense(1,activation="linear")(z)
        
    x=Model(inputs=inputL, outputs=z)
       
    return x

# %%
def go_train(n1,n2):
    
    num=1
    dir_path=dir_path=folder_path+'Trial-'+str(num)+'\\'
    while os.path.exists(dir_path):
        num=num+1
        dir_path=dir_path=folder_path+'Trial-'+str(num)+'\\'

    os.mkdir(dir_path)
    
    
    #NN parameter
    EPOCHS=40000
    #loss_function= 'mean_absolute_error' 
    loss_function= 'mean_squared_error'
    optimizer = tf.keras.optimizers.Adam(0.01)
    #optimizer = tf.keras.optimizers.RMSprop(0.01)
    kf=KFold(4,shuffle=True, random_state=0)

    fold=0
    r2_train=[]
    r2_test=[]
    rmse_train=[]
    rmse_test=[]
    mae_train=[]
    mae_test=[]
    e=[]

    early_stop=keras.callbacks.EarlyStopping(monitor='val_loss',min_delta=1,patience=50)

    for train, test in kf.split(x):
        fold+=1

        x_train=x[train]
        y_train=y[train]
        x_test=x[test]
        y_test=y[test]


        model=build_model(n1,n2)

        # compile model
        model.compile(loss=loss_function,optimizer=optimizer, metrics=['mean_absolute_error','mean_squared_error'])

        history= model.fit(x_train,y_train , epochs=EPOCHS, validation_data=(x_test,y_test), verbose = 0,callbacks=[early_stop])

        hist = pd.DataFrame(history.history)
        hist['epoch'] = history.epoch
        hist.to_csv(dir_path+'hist'+str(fold)+'.csv')
        
        
#         fig, (ax1,ax2)= plt.subplots(figsize=(12,4),nrows=1,ncols=2)
#         ax1.set_xlabel('Epoch')
#         ax1.set_ylabel('Mean Abs Error')
#         ax1.plot(hist['epoch'], hist['mean_absolute_error'],
#                                label='Train Error')
#         ax1.plot(hist['epoch'], hist['val_mean_absolute_error'],
#                                label='Val Error')
#         ax1.set_ylim([0,hist['mean_absolute_error'].iloc[0]])
#         ax1.legend()
      
        
#         ax2.set_xlabel('Epoch')
#         ax2.set_ylabel('Mean Square Error')
#         ax2.plot(hist['epoch'], hist['mean_squared_error'],
#                                label='Train Error')
#         ax2.plot(hist['epoch'], hist['val_mean_squared_error'],
#                                label='Val Error')
#         ax2.set_ylim([0,hist['mean_squared_error'].iloc[0]])
#         ax2.legend()
        
#         plt.tight_layout()
#         plt.show()
        
        train_predictions= model.predict(x_train).flatten()
        test_predictions= model.predict(x_test).flatten()

        name=dir_path+'pred_test'+str(fold)+'.csv'
        test_res=pd.DataFrame(x_test,columns=column_names_r)
        test_res['Hardness']=y_test
        test_res['Predict']=test_predictions
        test_res.to_csv(name)
                
        name=dir_path+'pred_train'+str(fold)+'.csv'
        train_res=pd.DataFrame(x_train,columns=column_names_r)
        train_res['Hardness']=y_train
        train_res['Predict']=train_predictions
        train_res.to_csv(name)
                


        r2_train.append(r2(y_train,train_predictions))
        r2_test.append(r2(y_test,test_predictions))
        rmse_train.append(rmse(y_train,train_predictions))
        rmse_test.append(rmse(y_test,test_predictions))
        mae_train.append(mae(y_train,train_predictions))
        mae_test.append(mae(y_test,test_predictions))
        e.append(hist['epoch'].tail(1).iloc[0])

    r2_train_f=np.mean(r2_train)
    r2_train_std=np.std(r2_train)
    r2_test_f=np.mean(r2_test)
    r2_test_std=np.std(r2_test)
    rmse_train_f=np.mean(rmse_train)
    rmse_train_std=np.std(rmse_train)
    rmse_test_f=np.mean(rmse_test)
    rmse_test_std=np.std(rmse_test)
    mae_train_f=np.mean(mae_train)
    mae_train_std=np.std(mae_train)
    mae_test_f=np.mean(mae_test)
    mae_test_std=np.std(mae_test)  
    e_mean=np.max(e)
    
    train_log_name='train_log.csv'
    columns=['Train_R2','Train_R2 std','Train_RSME','Train_RSME std','Train_MAE','Train_MAE std','Test_R2','Test_R2 std','Test_RSME','Test_RSME std','Test_MAE','Test_MAE std','Epoch']
#     columns_=['Network','Train_R2','std','Train_RSME','std','Train_MAE','std','Test_R2','std','Test_RSME','std','Test_MAE','std']
    
    temp=np.array([r2_train_f,r2_train_std,rmse_train_f,
                  rmse_train_std,mae_train_f,mae_train_std,r2_test_f,
                  r2_test_std,rmse_test_f,rmse_test_std,mae_test_f,mae_test_std,e_mean])
                  
    temp=temp.reshape(1,13)              
    
    dummy_1=pd.DataFrame(['Trial-'+str(num)+'(7 x '+str(n1)+' x '+str(n2)+' x 1)'],columns=['Network'])              
    dummy_2=pd.DataFrame(temp,columns=columns)
    dummy=pd.concat([dummy_1,dummy_2],axis=1)

    
    if os.path.exists(train_log_name)==False:
        train_log=dummy.copy()
        train_log.to_csv(train_log_name,index=False)
     
    
    else:
        train_log =pd.read_csv(train_log_name,skipinitialspace=True)
        train_log =pd.concat([train_log,dummy],axis=0,sort=False)
        train_log.to_csv(train_log_name,index=False)
        
    K.clear_session()
    print('Trial-',num,'is Finished')

# %%
for n1 in range(10,205,5):
    for n2 in range(10,205,5):
        go_train(n1,n2)
# Out:
# WARNING:tensorflow:From C:\Users\janpo\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Trial- 1 is Finished
# Trial- 2 is Finished
# Trial- 3 is Finished
# Trial- 4 is Finished
# Trial- 5 is Finished
# Trial- 6 is Finished
# Trial- 7 is Finished
# Trial- 8 is Finished
# Trial- 9 is Finished
# Trial- 10 is Finished
# Trial- 11 is Finished
# Trial- 12 is Finished
# Trial- 13 is Finished
# Trial- 14 is Finished
# Trial- 15 is Finished
# Trial- 16 is Finished
# Trial- 17 is Finished
# Trial- 18 is Finished
# Trial- 19 is Finished
# Trial- 20 is Finished
# Trial- 21 is Finished
# Trial- 22 is Finished
# Trial- 23 is Finished
# Trial- 24 is Finished
# Trial- 25 is Finished
# Trial- 26 is Finished
# Trial- 27 is Finished
# Trial- 28 is Finished
# Trial- 29 is Finished
# Trial- 30 is Finished
# Trial- 31 is Finished
# Trial- 32 is Finished
# Trial- 33 is Finished
# Trial- 34 is Finished
# Trial- 35 is Finished
# Trial- 36 is Finished
# Trial- 37 is Finished
# Trial- 38 is Finished
# Trial- 39 is Finished
# Trial- 40 is Finished
# Trial- 41 is Finished
# Trial- 42 is Finished
# Trial- 43 is Finished
# Trial- 44 is Finished
# Trial- 45 is Finished
# Trial- 46 is Finished
# Trial- 47 is Finished
# Trial- 48 is Finished
# Trial- 49 is Finished
# Trial- 50 is Finished
# Trial- 51 is Finished
# Trial- 52 is Finished
# Trial- 53 is Finished
# Trial- 54 is Finished
# Trial- 55 is Finished
# Trial- 56 is Finished
# Trial- 57 is Finished
# Trial- 58 is Finished
# Trial- 59 is Finished
# Trial- 60 is Finished
# Trial- 61 is Finished
# Trial- 62 is Finished
# Trial- 63 is Finished
# Trial- 64 is Finished
# Trial- 65 is Finished
# Trial- 66 is Finished
# Trial- 67 is Finished
# Trial- 68 is Finished
# Trial- 69 is Finished
# Trial- 70 is Finished
# Trial- 71 is Finished
# Trial- 72 is Finished
# Trial- 73 is Finished
# Trial- 74 is Finished
# Trial- 75 is Finished
# Trial- 76 is Finished
# Trial- 77 is Finished
# Trial- 78 is Finished
# Trial- 79 is Finished
# Trial- 80 is Finished
# Trial- 81 is Finished
# Trial- 82 is Finished
# Trial- 83 is Finished
# Trial- 84 is Finished
# Trial- 85 is Finished
# Trial- 86 is Finished
# Trial- 87 is Finished
# Trial- 88 is Finished
# Trial- 89 is Finished
# Trial- 90 is Finished
# Trial- 91 is Finished
# Trial- 92 is Finished
# Trial- 93 is Finished
# Trial- 94 is Finished
# Trial- 95 is Finished
# Trial- 96 is Finished
# Trial- 97 is Finished
# Trial- 98 is Finished
# Trial- 99 is Finished
# Trial- 100 is Finished
# Trial- 101 is Finished
# Trial- 102 is Finished
# Trial- 103 is Finished
# Trial- 104 is Finished
# Trial- 105 is Finished
# Trial- 106 is Finished
# Trial- 107 is Finished
# Trial- 108 is Finished
# Trial- 109 is Finished
# Trial- 110 is Finished
# Trial- 111 is Finished
# Trial- 112 is Finished
# Trial- 113 is Finished
# Trial- 114 is Finished
# Trial- 115 is Finished
# Trial- 116 is Finished
# Trial- 117 is Finished
# Trial- 118 is Finished
# Trial- 119 is Finished
# Trial- 120 is Finished
# Trial- 121 is Finished
# Trial- 122 is Finished
# Trial- 123 is Finished
# Trial- 124 is Finished
# Trial- 125 is Finished
# Trial- 126 is Finished
# Trial- 127 is Finished
# Trial- 128 is Finished
# Trial- 129 is Finished
# Trial- 130 is Finished
# Trial- 131 is Finished
# Trial- 132 is Finished
# Trial- 133 is Finished
# Trial- 134 is Finished
# Trial- 135 is Finished
# Trial- 136 is Finished
# Trial- 137 is Finished
# Trial- 138 is Finished
# Trial- 139 is Finished
# Trial- 140 is Finished
# Trial- 141 is Finished
# Trial- 142 is Finished
# Trial- 143 is Finished
# Trial- 144 is Finished
# Trial- 145 is Finished
# Trial- 146 is Finished
# Trial- 147 is Finished
# Trial- 148 is Finished
# Trial- 149 is Finished
# Trial- 150 is Finished
# Trial- 151 is Finished
# Trial- 152 is Finished
# Trial- 153 is Finished
# Trial- 154 is Finished
# Trial- 155 is Finished
# Trial- 156 is Finished
# Trial- 157 is Finished
# Trial- 158 is Finished
# Trial- 159 is Finished
# Trial- 160 is Finished
# Trial- 161 is Finished
# Trial- 162 is Finished
# Trial- 163 is Finished
# Trial- 164 is Finished
# Trial- 165 is Finished
# Trial- 166 is Finished
# Trial- 167 is Finished
# Trial- 168 is Finished
# Trial- 169 is Finished
# Trial- 170 is Finished
# Trial- 171 is Finished
# Trial- 172 is Finished
# Trial- 173 is Finished
# Trial- 174 is Finished
# Trial- 175 is Finished
# Trial- 176 is Finished
# Trial- 177 is Finished
# Trial- 178 is Finished
# Trial- 179 is Finished
# Trial- 180 is Finished
# Trial- 181 is Finished
# Trial- 182 is Finished
# Trial- 183 is Finished
# Trial- 184 is Finished
# Trial- 185 is Finished
# Trial- 186 is Finished
# Trial- 187 is Finished
# Trial- 188 is Finished
# Trial- 189 is Finished
# Trial- 190 is Finished
# Trial- 191 is Finished
# Trial- 192 is Finished
# Trial- 193 is Finished
# Trial- 194 is Finished
# Trial- 195 is Finished
# Trial- 196 is Finished
# Trial- 197 is Finished
# Trial- 198 is Finished
# Trial- 199 is Finished
# Trial- 200 is Finished
# Trial- 201 is Finished
# Trial- 202 is Finished
# Trial- 203 is Finished
# Trial- 204 is Finished
# Trial- 205 is Finished
# Trial- 206 is Finished
# Trial- 207 is Finished
# Trial- 208 is Finished
# Trial- 209 is Finished
# Trial- 210 is Finished
# Trial- 211 is Finished
# Trial- 212 is Finished
# Trial- 213 is Finished
# Trial- 214 is Finished
# Trial- 215 is Finished
# Trial- 216 is Finished
# Trial- 217 is Finished
# Trial- 218 is Finished
# Trial- 219 is Finished
# Trial- 220 is Finished
# Trial- 221 is Finished
# Trial- 222 is Finished
# Trial- 223 is Finished
# Trial- 224 is Finished
# Trial- 225 is Finished
# Trial- 226 is Finished
# Trial- 227 is Finished
# Trial- 228 is Finished
# Trial- 229 is Finished
# Trial- 230 is Finished
# Trial- 231 is Finished
# Trial- 232 is Finished
# Trial- 233 is Finished
# Trial- 234 is Finished
# Trial- 235 is Finished
# Trial- 236 is Finished
# Trial- 237 is Finished
# Trial- 238 is Finished
# Trial- 239 is Finished
# Trial- 240 is Finished
# Trial- 241 is Finished
# Trial- 242 is Finished
# Trial- 243 is Finished
# Trial- 244 is Finished
# Trial- 245 is Finished
# Trial- 246 is Finished
# Trial- 247 is Finished
# Trial- 248 is Finished
# Trial- 249 is Finished
# Trial- 250 is Finished
# Trial- 251 is Finished
# Trial- 252 is Finished
# Trial- 253 is Finished
# Trial- 254 is Finished
# Trial- 255 is Finished
# Trial- 256 is Finished
# Trial- 257 is Finished
# Trial- 258 is Finished
# Trial- 259 is Finished
# Trial- 260 is Finished
# Trial- 261 is Finished
# Trial- 262 is Finished
# Trial- 263 is Finished
# Trial- 264 is Finished
# Trial- 265 is Finished
# Trial- 266 is Finished
# Trial- 267 is Finished
# Trial- 268 is Finished
# Trial- 269 is Finished
# Trial- 270 is Finished
# Trial- 271 is Finished
# Trial- 272 is Finished
# Trial- 273 is Finished
# Trial- 274 is Finished
# Trial- 275 is Finished
# Trial- 276 is Finished
# Trial- 277 is Finished
# Trial- 278 is Finished
# Trial- 279 is Finished
# Trial- 280 is Finished
# Trial- 281 is Finished
# Trial- 282 is Finished
# Trial- 283 is Finished
# Trial- 284 is Finished
# Trial- 285 is Finished
# Trial- 286 is Finished
# Trial- 287 is Finished
# Trial- 288 is Finished
# Trial- 289 is Finished
# Trial- 290 is Finished
# Trial- 291 is Finished
# Trial- 292 is Finished
# Trial- 293 is Finished
# Trial- 294 is Finished
# Trial- 295 is Finished
# Trial- 296 is Finished
# Trial- 297 is Finished
# Trial- 298 is Finished
# Trial- 299 is Finished
# Trial- 300 is Finished
# Trial- 301 is Finished
# Trial- 302 is Finished
# Trial- 303 is Finished
# Trial- 304 is Finished
# Trial- 305 is Finished
# Trial- 306 is Finished
# Trial- 307 is Finished
# Trial- 308 is Finished
# Trial- 309 is Finished
# Trial- 310 is Finished
# Trial- 311 is Finished
# Trial- 312 is Finished
# Trial- 313 is Finished
# Trial- 314 is Finished
# Trial- 315 is Finished
# Trial- 316 is Finished
# Trial- 317 is Finished
# Trial- 318 is Finished
# Trial- 319 is Finished
# Trial- 320 is Finished
# Trial- 321 is Finished
# Trial- 322 is Finished
# Trial- 323 is Finished
# Trial- 324 is Finished
# Trial- 325 is Finished
# Trial- 326 is Finished
# Trial- 327 is Finished
# Trial- 328 is Finished
# Trial- 329 is Finished
# Trial- 330 is Finished
# Trial- 331 is Finished
# Trial- 332 is Finished
# Trial- 333 is Finished
# Trial- 334 is Finished
# Trial- 335 is Finished
# Trial- 336 is Finished
# Trial- 337 is Finished
# Trial- 338 is Finished
# Trial- 339 is Finished
# Trial- 340 is Finished
# Trial- 341 is Finished
# Trial- 342 is Finished
# Trial- 343 is Finished
# Trial- 344 is Finished
# Trial- 345 is Finished
# Trial- 346 is Finished
# Trial- 347 is Finished
# Trial- 348 is Finished
# Trial- 349 is Finished
# Trial- 350 is Finished
# Trial- 351 is Finished
# Trial- 352 is Finished
# Trial- 353 is Finished
# Trial- 354 is Finished
# Trial- 355 is Finished
# Trial- 356 is Finished
# Trial- 357 is Finished
# Trial- 358 is Finished
# Trial- 359 is Finished
# Trial- 360 is Finished
# Trial- 361 is Finished
# Trial- 362 is Finished
# Trial- 363 is Finished
# Trial- 364 is Finished
# Trial- 365 is Finished
# Trial- 366 is Finished
# Trial- 367 is Finished
# Trial- 368 is Finished
# Trial- 369 is Finished
# Trial- 370 is Finished
# Trial- 371 is Finished
# Trial- 372 is Finished
# Trial- 373 is Finished
# Trial- 374 is Finished
# Trial- 375 is Finished
# Trial- 376 is Finished
# Trial- 377 is Finished
# Trial- 378 is Finished
# Trial- 379 is Finished
# Trial- 380 is Finished
# Trial- 381 is Finished
# Trial- 382 is Finished
# Trial- 383 is Finished
# Trial- 384 is Finished
# Trial- 385 is Finished
# Trial- 386 is Finished
# Trial- 387 is Finished
# Trial- 388 is Finished
# Trial- 389 is Finished
# Trial- 390 is Finished
# Trial- 391 is Finished
# Trial- 392 is Finished
# Trial- 393 is Finished
# Trial- 394 is Finished
# Trial- 395 is Finished
# Trial- 396 is Finished
# Trial- 397 is Finished
# Trial- 398 is Finished
# Trial- 399 is Finished
# Trial- 400 is Finished
# Trial- 401 is Finished
# Trial- 402 is Finished
# Trial- 403 is Finished
# Trial- 404 is Finished
# Trial- 405 is Finished
# Trial- 406 is Finished
# Trial- 407 is Finished
# Trial- 408 is Finished
# Trial- 409 is Finished
# Trial- 410 is Finished
# Trial- 411 is Finished
# Trial- 412 is Finished
# Trial- 413 is Finished
# Trial- 414 is Finished
# Trial- 415 is Finished
# Trial- 416 is Finished
# Trial- 417 is Finished
# Trial- 418 is Finished
# Trial- 419 is Finished
# Trial- 420 is Finished
# Trial- 421 is Finished
# Trial- 422 is Finished
# Trial- 423 is Finished
# Trial- 424 is Finished
# Trial- 425 is Finished
# Trial- 426 is Finished
# Trial- 427 is Finished
# Trial- 428 is Finished
# Trial- 429 is Finished
# Trial- 430 is Finished
# Trial- 431 is Finished
# Trial- 432 is Finished
# Trial- 433 is Finished
# Trial- 434 is Finished
# Trial- 435 is Finished
# Trial- 436 is Finished
# Trial- 437 is Finished
# Trial- 438 is Finished
# Trial- 439 is Finished
# Trial- 440 is Finished
# Trial- 441 is Finished
# Trial- 442 is Finished
# Trial- 443 is Finished
# Trial- 444 is Finished
# Trial- 445 is Finished
# Trial- 446 is Finished
# Trial- 447 is Finished
# Trial- 448 is Finished
# Trial- 449 is Finished
# Trial- 450 is Finished
# Trial- 451 is Finished
# Trial- 452 is Finished
# Trial- 453 is Finished
# Trial- 454 is Finished
# Trial- 455 is Finished
# Trial- 456 is Finished
# Trial- 457 is Finished
# Trial- 458 is Finished
# Trial- 459 is Finished
# Trial- 460 is Finished
# Trial- 461 is Finished
# Trial- 462 is Finished
# Trial- 463 is Finished
# Trial- 464 is Finished
# Trial- 465 is Finished
# Trial- 466 is Finished
# Trial- 467 is Finished
# Trial- 468 is Finished
# Trial- 469 is Finished
# Trial- 470 is Finished
# Trial- 471 is Finished
# Trial- 472 is Finished
# Trial- 473 is Finished
# Trial- 474 is Finished
# Trial- 475 is Finished
# Trial- 476 is Finished
# Trial- 477 is Finished
# Trial- 478 is Finished
# Trial- 479 is Finished
# Trial- 480 is Finished
# Trial- 481 is Finished
# Trial- 482 is Finished
# Trial- 483 is Finished
# Trial- 484 is Finished
# Trial- 485 is Finished
# Trial- 486 is Finished
# Trial- 487 is Finished
# Trial- 488 is Finished
# Trial- 489 is Finished
# Trial- 490 is Finished
# Trial- 491 is Finished
# Trial- 492 is Finished
# Trial- 493 is Finished
# Trial- 494 is Finished
# Trial- 495 is Finished
# Trial- 496 is Finished
# Trial- 497 is Finished
# Trial- 498 is Finished
# Trial- 499 is Finished
# Trial- 500 is Finished
# Trial- 501 is Finished
# Trial- 502 is Finished
# Trial- 503 is Finished
# Trial- 504 is Finished
# Trial- 505 is Finished
# Trial- 506 is Finished
# Trial- 507 is Finished
# Trial- 508 is Finished
# Trial- 509 is Finished
# Trial- 510 is Finished
# Trial- 511 is Finished
# Trial- 512 is Finished
# Trial- 513 is Finished
# Trial- 514 is Finished
# Trial- 515 is Finished
# Trial- 516 is Finished
# Trial- 517 is Finished
# Trial- 518 is Finished
# Trial- 519 is Finished
# Trial- 520 is Finished
# Trial- 521 is Finished
# Trial- 522 is Finished
# Trial- 523 is Finished
# Trial- 524 is Finished
# Trial- 525 is Finished
# Trial- 526 is Finished
# Trial- 527 is Finished
# Trial- 528 is Finished
# Trial- 529 is Finished
# Trial- 530 is Finished
# Trial- 531 is Finished
# Trial- 532 is Finished
# Trial- 533 is Finished
# Trial- 534 is Finished
# Trial- 535 is Finished
# Trial- 536 is Finished
# Trial- 537 is Finished
# Trial- 538 is Finished
# Trial- 539 is Finished
# Trial- 540 is Finished
# Trial- 541 is Finished
# Trial- 542 is Finished
# Trial- 543 is Finished
# Trial- 544 is Finished
# Trial- 545 is Finished
# Trial- 546 is Finished
# Trial- 547 is Finished
# Trial- 548 is Finished
# Trial- 549 is Finished
# Trial- 550 is Finished
# Trial- 551 is Finished
# Trial- 552 is Finished
# Trial- 553 is Finished
# Trial- 554 is Finished
# Trial- 555 is Finished
# Trial- 556 is Finished
# Trial- 557 is Finished
# Trial- 558 is Finished
# Trial- 559 is Finished
# Trial- 560 is Finished
# Trial- 561 is Finished
# Trial- 562 is Finished
# Trial- 563 is Finished
# Trial- 564 is Finished
# Trial- 565 is Finished
# Trial- 566 is Finished
# Trial- 567 is Finished
# Trial- 568 is Finished
# Trial- 569 is Finished
# Trial- 570 is Finished
# Trial- 571 is Finished
# Trial- 572 is Finished
# Trial- 573 is Finished
# Trial- 574 is Finished
# Trial- 575 is Finished
# Trial- 576 is Finished
# Trial- 577 is Finished
# Trial- 578 is Finished
# Trial- 579 is Finished
# Trial- 580 is Finished
# Trial- 581 is Finished
# Trial- 582 is Finished
# Trial- 583 is Finished
# Trial- 584 is Finished
# Trial- 585 is Finished
# Trial- 586 is Finished
# Trial- 587 is Finished
# Trial- 588 is Finished
# Trial- 589 is Finished
# Trial- 590 is Finished
# Trial- 591 is Finished
# Trial- 592 is Finished
# Trial- 593 is Finished
# Trial- 594 is Finished
# Trial- 595 is Finished
# Trial- 596 is Finished
# Trial- 597 is Finished
# Trial- 598 is Finished
# Trial- 599 is Finished
# Trial- 600 is Finished
# Trial- 601 is Finished
# Trial- 602 is Finished
# Trial- 603 is Finished
# Trial- 604 is Finished
# Trial- 605 is Finished
# Trial- 606 is Finished
# Trial- 607 is Finished
# Trial- 608 is Finished
# Trial- 609 is Finished
# Trial- 610 is Finished
# Trial- 611 is Finished
# Trial- 612 is Finished
# Trial- 613 is Finished
# Trial- 614 is Finished
# Trial- 615 is Finished
# Trial- 616 is Finished
# Trial- 617 is Finished
# Trial- 618 is Finished
# Trial- 619 is Finished
# Trial- 620 is Finished
# Trial- 621 is Finished
# Trial- 622 is Finished
# Trial- 623 is Finished
# Trial- 624 is Finished
# Trial- 625 is Finished
# Trial- 626 is Finished
# Trial- 627 is Finished
# Trial- 628 is Finished
# Trial- 629 is Finished
# Trial- 630 is Finished
# Trial- 631 is Finished
# Trial- 632 is Finished
# Trial- 633 is Finished
# Trial- 634 is Finished
# Trial- 635 is Finished
# Trial- 636 is Finished
# Trial- 637 is Finished
# Trial- 638 is Finished
# Trial- 639 is Finished
# Trial- 640 is Finished
# Trial- 641 is Finished
# Trial- 642 is Finished
# Trial- 643 is Finished
# Trial- 644 is Finished
# Trial- 645 is Finished
# Trial- 646 is Finished
# Trial- 647 is Finished
# Trial- 648 is Finished
# Trial- 649 is Finished
# Trial- 650 is Finished
# Trial- 651 is Finished
# Trial- 652 is Finished
# Trial- 653 is Finished
# Trial- 654 is Finished
# Trial- 655 is Finished
# Trial- 656 is Finished
# Trial- 657 is Finished
# Trial- 658 is Finished
# Trial- 659 is Finished
# Trial- 660 is Finished
# Trial- 661 is Finished
# Trial- 662 is Finished
# Trial- 663 is Finished
# Trial- 664 is Finished
# Trial- 665 is Finished
# Trial- 666 is Finished
# Trial- 667 is Finished
# Trial- 668 is Finished
# Trial- 669 is Finished
# Trial- 670 is Finished
# Trial- 671 is Finished
# Trial- 672 is Finished
# Trial- 673 is Finished
# Trial- 674 is Finished
# Trial- 675 is Finished
# Trial- 676 is Finished
# Trial- 677 is Finished
# Trial- 678 is Finished
# Trial- 679 is Finished
# Trial- 680 is Finished
# Trial- 681 is Finished
# Trial- 682 is Finished
# Trial- 683 is Finished
# Trial- 684 is Finished
# Trial- 685 is Finished
# Trial- 686 is Finished
# Trial- 687 is Finished
# Trial- 688 is Finished
# Trial- 689 is Finished
# Trial- 690 is Finished
# Trial- 691 is Finished
# Trial- 692 is Finished
# Trial- 693 is Finished
# Trial- 694 is Finished
# Trial- 695 is Finished
# Trial- 696 is Finished
# Trial- 697 is Finished
# Trial- 698 is Finished
# Trial- 699 is Finished
# Trial- 700 is Finished
# Trial- 701 is Finished
# Trial- 702 is Finished
# Trial- 703 is Finished
# Trial- 704 is Finished
# Trial- 705 is Finished
# Trial- 706 is Finished
# Trial- 707 is Finished
# Trial- 708 is Finished
# Trial- 709 is Finished
# Trial- 710 is Finished
# Trial- 711 is Finished
# Trial- 712 is Finished
# Trial- 713 is Finished
# Trial- 714 is Finished
# Trial- 715 is Finished
# Trial- 716 is Finished
# Trial- 717 is Finished
# Trial- 718 is Finished
# Trial- 719 is Finished
# Trial- 720 is Finished
# Trial- 721 is Finished
# Trial- 722 is Finished
# Trial- 723 is Finished
# Trial- 724 is Finished
# Trial- 725 is Finished
# Trial- 726 is Finished
# Trial- 727 is Finished
# Trial- 728 is Finished
# Trial- 729 is Finished
# Trial- 730 is Finished
# Trial- 731 is Finished
# Trial- 732 is Finished
# Trial- 733 is Finished
# Trial- 734 is Finished
# Trial- 735 is Finished
# Trial- 736 is Finished
# Trial- 737 is Finished
# Trial- 738 is Finished
# Trial- 739 is Finished
# Trial- 740 is Finished
# Trial- 741 is Finished
# Trial- 742 is Finished
# Trial- 743 is Finished
# Trial- 744 is Finished
# Trial- 745 is Finished
# Trial- 746 is Finished
# Trial- 747 is Finished
# Trial- 748 is Finished
# Trial- 749 is Finished
# Trial- 750 is Finished
# Trial- 751 is Finished
# Trial- 752 is Finished
# Trial- 753 is Finished
# Trial- 754 is Finished
# Trial- 755 is Finished
# Trial- 756 is Finished
# Trial- 757 is Finished
# Trial- 758 is Finished
# Trial- 759 is Finished
# Trial- 760 is Finished
# Trial- 761 is Finished
# Trial- 762 is Finished
# Trial- 763 is Finished
# Trial- 764 is Finished
# Trial- 765 is Finished
# Trial- 766 is Finished
# Trial- 767 is Finished
# Trial- 768 is Finished
# Trial- 769 is Finished
# Trial- 770 is Finished
# Trial- 771 is Finished
# Trial- 772 is Finished
# Trial- 773 is Finished
# Trial- 774 is Finished
# Trial- 775 is Finished
# Trial- 776 is Finished
# Trial- 777 is Finished
# Trial- 778 is Finished
# Trial- 779 is Finished
# Trial- 780 is Finished
# Trial- 781 is Finished
# Trial- 782 is Finished
# Trial- 783 is Finished
# Trial- 784 is Finished
# Trial- 785 is Finished
# Trial- 786 is Finished
# Trial- 787 is Finished
# Trial- 788 is Finished
# Trial- 789 is Finished
# Trial- 790 is Finished
# Trial- 791 is Finished
# Trial- 792 is Finished
# Trial- 793 is Finished
# Trial- 794 is Finished
# Trial- 795 is Finished
# Trial- 796 is Finished
# Trial- 797 is Finished
# Trial- 798 is Finished
# Trial- 799 is Finished
# Trial- 800 is Finished
# Trial- 801 is Finished
# Trial- 802 is Finished
# Trial- 803 is Finished
# Trial- 804 is Finished
# Trial- 805 is Finished
# Trial- 806 is Finished
# Trial- 807 is Finished
# Trial- 808 is Finished
# Trial- 809 is Finished
# Trial- 810 is Finished
# Trial- 811 is Finished
# Trial- 812 is Finished
# Trial- 813 is Finished
# Trial- 814 is Finished
# Trial- 815 is Finished
# Trial- 816 is Finished
# Trial- 817 is Finished
# Trial- 818 is Finished
# Trial- 819 is Finished
# Trial- 820 is Finished
# Trial- 821 is Finished
# Trial- 822 is Finished
# Trial- 823 is Finished
# Trial- 824 is Finished
# Trial- 825 is Finished
# Trial- 826 is Finished
# Trial- 827 is Finished
# Trial- 828 is Finished
# Trial- 829 is Finished
# Trial- 830 is Finished
# Trial- 831 is Finished
# Trial- 832 is Finished
# Trial- 833 is Finished
# Trial- 834 is Finished
# Trial- 835 is Finished
# Trial- 836 is Finished
# Trial- 837 is Finished
# Trial- 838 is Finished
# Trial- 839 is Finished
# Trial- 840 is Finished
# Trial- 841 is Finished
# Trial- 842 is Finished
# Trial- 843 is Finished
# Trial- 844 is Finished
# Trial- 845 is Finished
# Trial- 846 is Finished
# Trial- 847 is Finished
# Trial- 848 is Finished
# Trial- 849 is Finished
# Trial- 850 is Finished
# Trial- 851 is Finished
# Trial- 852 is Finished
# Trial- 853 is Finished
# Trial- 854 is Finished
# Trial- 855 is Finished
# Trial- 856 is Finished
# Trial- 857 is Finished
# Trial- 858 is Finished
# Trial- 859 is Finished
# Trial- 860 is Finished
# Trial- 861 is Finished
# Trial- 862 is Finished
# Trial- 863 is Finished
# Trial- 864 is Finished
# Trial- 865 is Finished
# Trial- 866 is Finished
# Trial- 867 is Finished
# Trial- 868 is Finished
# Trial- 869 is Finished
# Trial- 870 is Finished
# Trial- 871 is Finished
# Trial- 872 is Finished
# Trial- 873 is Finished
# Trial- 874 is Finished
# Trial- 875 is Finished
# Trial- 876 is Finished
# Trial- 877 is Finished
# Trial- 878 is Finished
# Trial- 879 is Finished
# Trial- 880 is Finished
# Trial- 881 is Finished
# Trial- 882 is Finished
# Trial- 883 is Finished
# Trial- 884 is Finished
# Trial- 885 is Finished
# Trial- 886 is Finished
# Trial- 887 is Finished
# Trial- 888 is Finished
# Trial- 889 is Finished
# Trial- 890 is Finished
# Trial- 891 is Finished
# Trial- 892 is Finished
# Trial- 893 is Finished
# Trial- 894 is Finished
# Trial- 895 is Finished
# Trial- 896 is Finished
# Trial- 897 is Finished
# Trial- 898 is Finished
# Trial- 899 is Finished
# Trial- 900 is Finished
# Trial- 901 is Finished
# Trial- 902 is Finished
# Trial- 903 is Finished
# Trial- 904 is Finished
# Trial- 905 is Finished
# Trial- 906 is Finished
# Trial- 907 is Finished
# Trial- 908 is Finished
# Trial- 909 is Finished
# Trial- 910 is Finished
# Trial- 911 is Finished
# Trial- 912 is Finished
# Trial- 913 is Finished
# Trial- 914 is Finished
# Trial- 915 is Finished
# Trial- 916 is Finished
# Trial- 917 is Finished
# Trial- 918 is Finished
# Trial- 919 is Finished
# Trial- 920 is Finished
# Trial- 921 is Finished
# Trial- 922 is Finished
# Trial- 923 is Finished
# Trial- 924 is Finished
# Trial- 925 is Finished
# Trial- 926 is Finished
# Trial- 927 is Finished
# Trial- 928 is Finished
# Trial- 929 is Finished
# Trial- 930 is Finished
# Trial- 931 is Finished
# Trial- 932 is Finished
# Trial- 933 is Finished
# Trial- 934 is Finished
# Trial- 935 is Finished
# Trial- 936 is Finished
# Trial- 937 is Finished
# Trial- 938 is Finished
# Trial- 939 is Finished
# Trial- 940 is Finished
# Trial- 941 is Finished
# Trial- 942 is Finished
# Trial- 943 is Finished
# Trial- 944 is Finished
# Trial- 945 is Finished
# Trial- 946 is Finished
# Trial- 947 is Finished
# Trial- 948 is Finished
# Trial- 949 is Finished
# Trial- 950 is Finished
# Trial- 951 is Finished
# Trial- 952 is Finished
# Trial- 953 is Finished
# Trial- 954 is Finished
# Trial- 955 is Finished
# Trial- 956 is Finished
# Trial- 957 is Finished
# Trial- 958 is Finished
# Trial- 959 is Finished
# Trial- 960 is Finished
# Trial- 961 is Finished
# Trial- 962 is Finished
# Trial- 963 is Finished
# Trial- 964 is Finished
# Trial- 965 is Finished
# Trial- 966 is Finished
# Trial- 967 is Finished
# Trial- 968 is Finished
# Trial- 969 is Finished
# Trial- 970 is Finished
# Trial- 971 is Finished
# Trial- 972 is Finished
# Trial- 973 is Finished
# Trial- 974 is Finished
# Trial- 975 is Finished
# Trial- 976 is Finished
# Trial- 977 is Finished
# Trial- 978 is Finished
# Trial- 979 is Finished
# Trial- 980 is Finished
# Trial- 981 is Finished
# Trial- 982 is Finished
# Trial- 983 is Finished
# Trial- 984 is Finished
# Trial- 985 is Finished
# Trial- 986 is Finished
# Trial- 987 is Finished
# Trial- 988 is Finished
# Trial- 989 is Finished
# Trial- 990 is Finished
# Trial- 991 is Finished
# Trial- 992 is Finished
# Trial- 993 is Finished
# Trial- 994 is Finished
# Trial- 995 is Finished
# Trial- 996 is Finished
# Trial- 997 is Finished
# Trial- 998 is Finished
# Trial- 999 is Finished
# Trial- 1000 is Finished
# Trial- 1001 is Finished
# Trial- 1002 is Finished
# Trial- 1003 is Finished
# Trial- 1004 is Finished
# Trial- 1005 is Finished
# Trial- 1006 is Finished
# Trial- 1007 is Finished
# Trial- 1008 is Finished
# Trial- 1009 is Finished
# Trial- 1010 is Finished
# Trial- 1011 is Finished
# Trial- 1012 is Finished
# Trial- 1013 is Finished
# Trial- 1014 is Finished
# Trial- 1015 is Finished
# Trial- 1016 is Finished
# Trial- 1017 is Finished
# Trial- 1018 is Finished
# Trial- 1019 is Finished
# Trial- 1020 is Finished
# Trial- 1021 is Finished
# Trial- 1022 is Finished
# Trial- 1023 is Finished
# Trial- 1024 is Finished
# Trial- 1025 is Finished
# Trial- 1026 is Finished
# Trial- 1027 is Finished
# Trial- 1028 is Finished
# Trial- 1029 is Finished
# Trial- 1030 is Finished
# Trial- 1031 is Finished
# Trial- 1032 is Finished
# Trial- 1033 is Finished
# Trial- 1034 is Finished
# Trial- 1035 is Finished
# Trial- 1036 is Finished
# Trial- 1037 is Finished
# Trial- 1038 is Finished
# Trial- 1039 is Finished
# Trial- 1040 is Finished
# Trial- 1041 is Finished
# Trial- 1042 is Finished
# Trial- 1043 is Finished
# Trial- 1044 is Finished
# Trial- 1045 is Finished
# Trial- 1046 is Finished
# Trial- 1047 is Finished
# Trial- 1048 is Finished
# Trial- 1049 is Finished
# Trial- 1050 is Finished
# Trial- 1051 is Finished
# Trial- 1052 is Finished
# Trial- 1053 is Finished
# Trial- 1054 is Finished
# Trial- 1055 is Finished
# Trial- 1056 is Finished
# Trial- 1057 is Finished
# Trial- 1058 is Finished
# Trial- 1059 is Finished
# Trial- 1060 is Finished
# Trial- 1061 is Finished
# Trial- 1062 is Finished
# Trial- 1063 is Finished
# Trial- 1064 is Finished
# Trial- 1065 is Finished
# Trial- 1066 is Finished
# Trial- 1067 is Finished
# Trial- 1068 is Finished
# Trial- 1069 is Finished
# Trial- 1070 is Finished
# Trial- 1071 is Finished
# Trial- 1072 is Finished
# Trial- 1073 is Finished
# Trial- 1074 is Finished
# Trial- 1075 is Finished
# Trial- 1076 is Finished
# Trial- 1077 is Finished
# Trial- 1078 is Finished
# Trial- 1079 is Finished
# Trial- 1080 is Finished
# Trial- 1081 is Finished
# Trial- 1082 is Finished
# Trial- 1083 is Finished
# Trial- 1084 is Finished
# Trial- 1085 is Finished
# Trial- 1086 is Finished
# Trial- 1087 is Finished
# Trial- 1088 is Finished
# Trial- 1089 is Finished
# Trial- 1090 is Finished
# Trial- 1091 is Finished
# Trial- 1092 is Finished
# Trial- 1093 is Finished
# Trial- 1094 is Finished
# Trial- 1095 is Finished
# Trial- 1096 is Finished
# Trial- 1097 is Finished
# Trial- 1098 is Finished
# Trial- 1099 is Finished
# Trial- 1100 is Finished
# Trial- 1101 is Finished
# Trial- 1102 is Finished
# Trial- 1103 is Finished
# Trial- 1104 is Finished
# Trial- 1105 is Finished
# Trial- 1106 is Finished
# Trial- 1107 is Finished
# Trial- 1108 is Finished
# Trial- 1109 is Finished
# Trial- 1110 is Finished
# Trial- 1111 is Finished
# Trial- 1112 is Finished
# Trial- 1113 is Finished
# Trial- 1114 is Finished
# Trial- 1115 is Finished
# Trial- 1116 is Finished
# Trial- 1117 is Finished
# Trial- 1118 is Finished
# Trial- 1119 is Finished
# Trial- 1120 is Finished
# Trial- 1121 is Finished
# Trial- 1122 is Finished
# Trial- 1123 is Finished
# Trial- 1124 is Finished
# Trial- 1125 is Finished
# Trial- 1126 is Finished
# Trial- 1127 is Finished
# Trial- 1128 is Finished
# Trial- 1129 is Finished
# Trial- 1130 is Finished
# Trial- 1131 is Finished
# Trial- 1132 is Finished
# Trial- 1133 is Finished
# Trial- 1134 is Finished
# Trial- 1135 is Finished
# Trial- 1136 is Finished
# Trial- 1137 is Finished
# Trial- 1138 is Finished
# Trial- 1139 is Finished
# Trial- 1140 is Finished
# Trial- 1141 is Finished
# Trial- 1142 is Finished
# Trial- 1143 is Finished
# Trial- 1144 is Finished
# Trial- 1145 is Finished
# Trial- 1146 is Finished
# Trial- 1147 is Finished
# Trial- 1148 is Finished
# Trial- 1149 is Finished
# Trial- 1150 is Finished
# Trial- 1151 is Finished
# Trial- 1152 is Finished
# Trial- 1153 is Finished
# Trial- 1154 is Finished
# Trial- 1155 is Finished
# Trial- 1156 is Finished
# Trial- 1157 is Finished
# Trial- 1158 is Finished
# Trial- 1159 is Finished
# Trial- 1160 is Finished
# Trial- 1161 is Finished
# Trial- 1162 is Finished
# Trial- 1163 is Finished
# Trial- 1164 is Finished
# Trial- 1165 is Finished
# Trial- 1166 is Finished
# Trial- 1167 is Finished
# Trial- 1168 is Finished
# Trial- 1169 is Finished
# Trial- 1170 is Finished
# Trial- 1171 is Finished
# Trial- 1172 is Finished
# Trial- 1173 is Finished
# Trial- 1174 is Finished
# Trial- 1175 is Finished
# Trial- 1176 is Finished
# Trial- 1177 is Finished
# Trial- 1178 is Finished
# Trial- 1179 is Finished
# Trial- 1180 is Finished
# Trial- 1181 is Finished
# Trial- 1182 is Finished
# Trial- 1183 is Finished
# Trial- 1184 is Finished
# Trial- 1185 is Finished
# Trial- 1186 is Finished
# Trial- 1187 is Finished
# Trial- 1188 is Finished
# Trial- 1189 is Finished
# Trial- 1190 is Finished
# Trial- 1191 is Finished
# Trial- 1192 is Finished
# Trial- 1193 is Finished
# Trial- 1194 is Finished
# Trial- 1195 is Finished
# Trial- 1196 is Finished
# Trial- 1197 is Finished
# Trial- 1198 is Finished
# Trial- 1199 is Finished
# Trial- 1200 is Finished
# Trial- 1201 is Finished
# Trial- 1202 is Finished
# Trial- 1203 is Finished
# Trial- 1204 is Finished
# Trial- 1205 is Finished
# Trial- 1206 is Finished
# Trial- 1207 is Finished
# Trial- 1208 is Finished
# Trial- 1209 is Finished
# Trial- 1210 is Finished
# Trial- 1211 is Finished
# Trial- 1212 is Finished
# Trial- 1213 is Finished
# Trial- 1214 is Finished
# Trial- 1215 is Finished
# Trial- 1216 is Finished
# Trial- 1217 is Finished
# Trial- 1218 is Finished
# Trial- 1219 is Finished
# Trial- 1220 is Finished
# Trial- 1221 is Finished
# Trial- 1222 is Finished
# Trial- 1223 is Finished
# Trial- 1224 is Finished
# Trial- 1225 is Finished
# Trial- 1226 is Finished
# Trial- 1227 is Finished
# Trial- 1228 is Finished
# Trial- 1229 is Finished
# Trial- 1230 is Finished
# Trial- 1231 is Finished
# Trial- 1232 is Finished
# Trial- 1233 is Finished
# Trial- 1234 is Finished
# Trial- 1235 is Finished
# Trial- 1236 is Finished
# Trial- 1237 is Finished
# Trial- 1238 is Finished
# Trial- 1239 is Finished
# Trial- 1240 is Finished
# Trial- 1241 is Finished
# Trial- 1242 is Finished
# Trial- 1243 is Finished
# Trial- 1244 is Finished
# Trial- 1245 is Finished
# Trial- 1246 is Finished
# Trial- 1247 is Finished
# Trial- 1248 is Finished
# Trial- 1249 is Finished
# Trial- 1250 is Finished
# Trial- 1251 is Finished
# Trial- 1252 is Finished
# Trial- 1253 is Finished
# Trial- 1254 is Finished
# Trial- 1255 is Finished
# Trial- 1256 is Finished
# Trial- 1257 is Finished
# Trial- 1258 is Finished
# Trial- 1259 is Finished
# Trial- 1260 is Finished
# Trial- 1261 is Finished
# Trial- 1262 is Finished
# Trial- 1263 is Finished
# Trial- 1264 is Finished
# Trial- 1265 is Finished
# Trial- 1266 is Finished
# Trial- 1267 is Finished
# Trial- 1268 is Finished
# Trial- 1269 is Finished
# Trial- 1270 is Finished
# Trial- 1271 is Finished
# Trial- 1272 is Finished
# Trial- 1273 is Finished
# Trial- 1274 is Finished
# Trial- 1275 is Finished
# Trial- 1276 is Finished
# Trial- 1277 is Finished
# Trial- 1278 is Finished
# Trial- 1279 is Finished
# Trial- 1280 is Finished
# Trial- 1281 is Finished
# Trial- 1282 is Finished
# Trial- 1283 is Finished
# Trial- 1284 is Finished
# Trial- 1285 is Finished
# Trial- 1286 is Finished
# Trial- 1287 is Finished
# Trial- 1288 is Finished
# Trial- 1289 is Finished
# Trial- 1290 is Finished
# Trial- 1291 is Finished
# Trial- 1292 is Finished
# Trial- 1293 is Finished
# Trial- 1294 is Finished
# Trial- 1295 is Finished
# Trial- 1296 is Finished
# Trial- 1297 is Finished
# Trial- 1298 is Finished
# Trial- 1299 is Finished
# Trial- 1300 is Finished
# Trial- 1301 is Finished
# Trial- 1302 is Finished
# Trial- 1303 is Finished
# Trial- 1304 is Finished
# Trial- 1305 is Finished
# Trial- 1306 is Finished
# Trial- 1307 is Finished
# Trial- 1308 is Finished
# Trial- 1309 is Finished
# Trial- 1310 is Finished
# Trial- 1311 is Finished
# Trial- 1312 is Finished
# Trial- 1313 is Finished
# Trial- 1314 is Finished
# Trial- 1315 is Finished
# Trial- 1316 is Finished
# Trial- 1317 is Finished
# Trial- 1318 is Finished
# Trial- 1319 is Finished
# Trial- 1320 is Finished
# Trial- 1321 is Finished
# Trial- 1322 is Finished
# Trial- 1323 is Finished
# Trial- 1324 is Finished
# Trial- 1325 is Finished
# Trial- 1326 is Finished
# Trial- 1327 is Finished
# Trial- 1328 is Finished
# Trial- 1329 is Finished
# Trial- 1330 is Finished
# Trial- 1331 is Finished
# Trial- 1332 is Finished
# Trial- 1333 is Finished
# Trial- 1334 is Finished
# Trial- 1335 is Finished
# Trial- 1336 is Finished
# Trial- 1337 is Finished
# Trial- 1338 is Finished
# Trial- 1339 is Finished
# Trial- 1340 is Finished
# Trial- 1341 is Finished
# Trial- 1342 is Finished
# Trial- 1343 is Finished
# Trial- 1344 is Finished
# Trial- 1345 is Finished
# Trial- 1346 is Finished
# Trial- 1347 is Finished
# Trial- 1348 is Finished
# Trial- 1349 is Finished
# Trial- 1350 is Finished
# Trial- 1351 is Finished
# Trial- 1352 is Finished
# Trial- 1353 is Finished
# Trial- 1354 is Finished
# Trial- 1355 is Finished
# Trial- 1356 is Finished
# Trial- 1357 is Finished
# Trial- 1358 is Finished
# Trial- 1359 is Finished
# Trial- 1360 is Finished
# Trial- 1361 is Finished
# Trial- 1362 is Finished
# Trial- 1363 is Finished
# Trial- 1364 is Finished
# Trial- 1365 is Finished
# Trial- 1366 is Finished
# Trial- 1367 is Finished
# Trial- 1368 is Finished
# Trial- 1369 is Finished
# Trial- 1370 is Finished
# Trial- 1371 is Finished
# Trial- 1372 is Finished
# Trial- 1373 is Finished
# Trial- 1374 is Finished
# Trial- 1375 is Finished
# Trial- 1376 is Finished
# Trial- 1377 is Finished
# Trial- 1378 is Finished
# Trial- 1379 is Finished
# Trial- 1380 is Finished
# Trial- 1381 is Finished
# Trial- 1382 is Finished
# Trial- 1383 is Finished
# Trial- 1384 is Finished
# Trial- 1385 is Finished
# Trial- 1386 is Finished
# Trial- 1387 is Finished
# Trial- 1388 is Finished
# Trial- 1389 is Finished
# Trial- 1390 is Finished
# Trial- 1391 is Finished
# Trial- 1392 is Finished
# Trial- 1393 is Finished
# Trial- 1394 is Finished
# Trial- 1395 is Finished
# Trial- 1396 is Finished
# Trial- 1397 is Finished
# Trial- 1398 is Finished
# Trial- 1399 is Finished
# Trial- 1400 is Finished
# Trial- 1401 is Finished
# Trial- 1402 is Finished
# Trial- 1403 is Finished
# Trial- 1404 is Finished
# Trial- 1405 is Finished
# Trial- 1406 is Finished
# Trial- 1407 is Finished
# Trial- 1408 is Finished
# Trial- 1409 is Finished
# Trial- 1410 is Finished
# Trial- 1411 is Finished
# Trial- 1412 is Finished
# Trial- 1413 is Finished
# Trial- 1414 is Finished
# Trial- 1415 is Finished
# Trial- 1416 is Finished
# Trial- 1417 is Finished
# Trial- 1418 is Finished
# Trial- 1419 is Finished
# Trial- 1420 is Finished
# Trial- 1421 is Finished
# Trial- 1422 is Finished
# Trial- 1423 is Finished
# Trial- 1424 is Finished
# Trial- 1425 is Finished
# Trial- 1426 is Finished
# Trial- 1427 is Finished
# Trial- 1428 is Finished
# Trial- 1429 is Finished
# Trial- 1430 is Finished
# Trial- 1431 is Finished
# Trial- 1432 is Finished
# Trial- 1433 is Finished
# Trial- 1434 is Finished
# Trial- 1435 is Finished
# Trial- 1436 is Finished
# Trial- 1437 is Finished
# Trial- 1438 is Finished
# Trial- 1439 is Finished
# Trial- 1440 is Finished
# Trial- 1441 is Finished
# Trial- 1442 is Finished
# Trial- 1443 is Finished
# Trial- 1444 is Finished
# Trial- 1445 is Finished
# Trial- 1446 is Finished
# Trial- 1447 is Finished
# Trial- 1448 is Finished
# Trial- 1449 is Finished
# Trial- 1450 is Finished
# Trial- 1451 is Finished
# Trial- 1452 is Finished
# Trial- 1453 is Finished
# Trial- 1454 is Finished
# Trial- 1455 is Finished
# Trial- 1456 is Finished
# Trial- 1457 is Finished
# Trial- 1458 is Finished
# Trial- 1459 is Finished
# Trial- 1460 is Finished
# Trial- 1461 is Finished
# Trial- 1462 is Finished
# Trial- 1463 is Finished
# Trial- 1464 is Finished
# Trial- 1465 is Finished
# Trial- 1466 is Finished
# Trial- 1467 is Finished
# Trial- 1468 is Finished
# Trial- 1469 is Finished
# Trial- 1470 is Finished
# Trial- 1471 is Finished
# Trial- 1472 is Finished
# Trial- 1473 is Finished
# Trial- 1474 is Finished
# Trial- 1475 is Finished
# Trial- 1476 is Finished
# Trial- 1477 is Finished
# Trial- 1478 is Finished
# Trial- 1479 is Finished
# Trial- 1480 is Finished
# Trial- 1481 is Finished
# Trial- 1482 is Finished
# Trial- 1483 is Finished
# Trial- 1484 is Finished
# Trial- 1485 is Finished
# Trial- 1486 is Finished
# Trial- 1487 is Finished
# Trial- 1488 is Finished
# Trial- 1489 is Finished
# Trial- 1490 is Finished
# Trial- 1491 is Finished
# Trial- 1492 is Finished
# Trial- 1493 is Finished
# Trial- 1494 is Finished
# Trial- 1495 is Finished
# Trial- 1496 is Finished
# Trial- 1497 is Finished
# Trial- 1498 is Finished
# Trial- 1499 is Finished
# Trial- 1500 is Finished
# Trial- 1501 is Finished
# Trial- 1502 is Finished
# Trial- 1503 is Finished
# Trial- 1504 is Finished
# Trial- 1505 is Finished
# Trial- 1506 is Finished
# Trial- 1507 is Finished
# Trial- 1508 is Finished
# Trial- 1509 is Finished
# Trial- 1510 is Finished
# Trial- 1511 is Finished
# Trial- 1512 is Finished
# Trial- 1513 is Finished
# Trial- 1514 is Finished
# Trial- 1515 is Finished
# Trial- 1516 is Finished
# Trial- 1517 is Finished
# Trial- 1518 is Finished
# Trial- 1519 is Finished
# Trial- 1520 is Finished
# Trial- 1521 is Finished

# %% [markdown]
# # For building final model

# %%
# get dataset from csv file

path='Final Model\\'

if os.path.exists(path)==False:
    os.mkdir(path)

def build_model(n1,n2):
    inputL = Input(shape=(7,))

        
    z=Dense(n1,activation="relu")(inputL)
    z=Dense(n2,activation="relu")(z)
    z=Dense(1,activation="linear")(z)
        
    x=Model(inputs=inputL, outputs=z)
       
    return x
 
#NN parameter
EPOCHS=40000
#loss_function= 'mean_absolute_error' 
loss_function= 'mean_squared_error'
optimizer = tf.keras.optimizers.Adam(0.01)
#optimizer = tf.keras.optimizers.RMSprop(lr[a])

#directory setting
num=1
dir_path=path+'Trial-'+str(num)+'\\'
while os.path.exists(dir_path):
    num=num+1
    dir_path=path+'Trial-'+str(num)+'\\'

os.mkdir(dir_path)
print('Trial-',num)
x_train=x


class SaveModel(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
      if epoch%25==1:
            model.save(dir_path+'model'+str(epoch)+'.h5')
early_stop=keras.callbacks.EarlyStopping(monitor='val_loss',mode='min',min_delta=1,patience=25)

model=build_model(110,200)

# compile model
model.compile(loss=loss_function,optimizer=optimizer, metrics=['mean_absolute_error','mean_squared_error'])

history= model.fit(x_train,y , epochs=EPOCHS+1, validation_data=(x_val,y_val),verbose = 0,callbacks=[SaveModel(),early_stop])

model.save(dir_path+'model.h5')

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

hist.to_csv(dir_path+'error.csv')

plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Mean Abs Error')
plt.plot(hist['epoch'], hist['mean_absolute_error'],
                       label='Train Error')
plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
                       label='Val Train Error')
plt.ylim([0,hist['mean_absolute_error'].iloc[0]])
plt.legend()
plt.show()

plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(hist['epoch'], hist['mean_squared_error'],
                       label='Train Error')
plt.plot(hist['epoch'], hist['val_mean_squared_error'],
                       label='Val Train Error')
plt.ylim([0,hist['mean_squared_error'].iloc[0]])
plt.legend()
plt.show()

train_predictions= model.predict(x_train).flatten()

dataset=raw_dataset.copy()
dataset['Predict']=train_predictions
dataset.to_csv(dir_path+'train.csv')


plt.figure()
plt.scatter(y, train_predictions,color='b')
plt.xlabel('Experimental Values')
plt.ylabel('Prediction Values')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,400])
plt.ylim([0,400])
_ = plt.plot([-2000, 2000], [-2000, 2000])
plt.show()

# plot_model(model, to_file=dir_path+'model_plot_1.png', show_shapes=True, show_layer_names=True)

r2_train=r2(y,train_predictions)
rmse_train=rmse(y,train_predictions)
mae_train=mae(y,train_predictions)

test_predictions= model.predict(x_val).flatten()

dataset2=raw_dataset2.copy()
dataset2['Predict']=test_predictions
dataset2.to_csv(dir_path+'test.csv')


plt.figure()
plt.scatter(y_val, test_predictions,color='r')
plt.xlabel('Experimental Values')
plt.ylabel('Prediction Values')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,400])
plt.ylim([0,400])
_ = plt.plot([-2000, 2000], [-2000, 2000])
plt.show()

# plot_model(model, to_file=dir_path+'model_plot_1.png', show_shapes=True, show_layer_names=True)

xr2_train=r2(y_val,test_predictions)
xrmse_train=rmse(y_val,test_predictions)
xmae_train=mae(y_val,test_predictions)



print('Epoch : ', str(hist['epoch'].tail(1).iloc[0])) 
print('TRAINING : ' ,' R2 :',str(r2_train),'RSME :',str(rmse_train),' MAE :',str(mae_train))
print('TEST : ' ,' R2 :',str(xr2_train),'RSME :',str(xrmse_train),' MAE :',str(xmae_train))
K.clear_session()
# Out:
# Trial- 3
# Epoch :  92
# TRAINING :   R2 : 0.9821072395900345 RSME : 7.848022936611346  MAE : 4.404967105525142
# TEST :   R2 : 0.9605397627205536 RSME : 18.36152611996204  MAE : 14.08472859998007

# %% [markdown]
# # Re-Test

# %%
dir_path='Final Model\\Trial-2\\'
load_path=dir_path+'model.h5'
model = keras.models.load_model(load_path)
x_train=x

train_predictions= model.predict(x_train).flatten()

dataset=raw_dataset.copy()
dataset['Predict']=train_predictions
dataset.to_csv(dir_path+'train.csv')


plt.figure()
plt.scatter(y, train_predictions,color='b')
plt.xlabel('Experimental Values')
plt.ylabel('Prediction Values')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,1000])
plt.ylim([0,1000])
_ = plt.plot([-2000, 2000], [-2000, 2000])
plt.show()



r2_train=r2(y,train_predictions)
rmse_train=rmse(y,train_predictions)
mae_train=mae(y,train_predictions)

test_predictions= model.predict(x_val).flatten()

dataset2=raw_dataset2.copy()
dataset2['Predict']=test_predictions
dataset2.to_csv(dir_path+'test.csv')


plt.figure()
plt.scatter(y_val, test_predictions,color='r')
plt.xlabel('Experimental Values')
plt.ylabel('Prediction Values')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,1000])
plt.ylim([0,1000])
_ = plt.plot([-2000, 2000], [-2000, 2000],color='k')
plt.show()



xr2_train=r2(y_val,test_predictions)
xrmse_train=rmse(y_val,test_predictions)
xmae_train=mae(y_val,test_predictions)



# print('Epoch : ', str(hist['epoch'].tail(1).iloc[0])) 
print('TRAINING : ' ,' R2 :',str(r2_train),'RSME :',str(rmse_train),' MAE :',str(mae_train))
print('TEST : ' ,' R2 :',str(xr2_train),'RSME :',str(xrmse_train),' MAE :',str(xmae_train))
K.clear_session()
# Out:
# TRAINING :   R2 : 0.9893211289657775 RSME : 6.05841968268297  MAE : 3.556442691424421
# TEST :   R2 : 0.9364242135400433 RSME : 21.537812192767518  MAE : 14.56750611021712

# %% [markdown]
# # Predict in Batch

# %% [markdown]
# For Static force vs depth

# %%
#insert parameter 
def set_mat(material):
    
    if material =='718':
        uts=250
        ys=17.62
        hard=250
        cr=18.84
    if material =='718p':
        uts=684
        ys=9.5
        hard=250
        cr=18.84
    elif material=='600':
        uts=185
        ys=9.42
        hard=160
        cr=16.35
    elif material=='690':
        uts=211
        ys=11.6
        hard=211
        cr=29.9
    return uts,ys,hard,cr

load_path='Final Model\\Trial-1\model.h5'
model = keras.models.load_model(load_path)

# %%
uts,ys,hard,cr=set_mat('600')

# %%
st_force=10
amp=30
num_strike=8571
max_depth=2000

data=np.zeros(((max_depth+1),7))
 
data[:,0]=uts
data[:,1]=ys
data[:,2]=cr
data[:,6]=amp
data[:,4]=num_strike
data[:,3]=np.arange(max_depth+1)

#loaded model

model = keras.models.load_model(load_path)

for z in range(10):
    z=z+1
    
    data[:,5]=st_force*z
    #normalization
    normed=norm(data)
    

    temp=pd.DataFrame(data,columns=column_names_r)
    test_predictions= model.predict(normed).flatten()
    temp['Prediction']=test_predictions
    
    if z==1:
        res=temp.copy()
    else:
        res=res.append(temp,ignore_index=True, sort=False)




static=res[['Depth','Static Force','Prediction']]


X=res['Depth'].values
Y=res['Static Force'].values
Z=res['Prediction'].values
X=X.reshape((10, 2001))
Y=Y.reshape((10, 2001))
Z=Z.reshape((10, 2001))
plt.figure(figsize=(7,5))
plt.xlabel('Depth')
plt.ylabel('Static Force')
plt.contourf( X[0,:],Y[:,0],Z, cmap='RdBu')
clb = plt.colorbar()
clb.ax.set_title('Hardness')
plt.show()

# %% [markdown]
# For amplitude vs depth

# %%
st_force=30
amp=10
num_strike=8571
max_depth=2000

data=np.zeros(((max_depth+1),7))

data[:,0]=uts
data[:,1]=ys
data[:,2]=cr
data[:,5]=st_force
data[:,4]=num_strike
data[:,3]=np.arange(max_depth+1)

#loaded model

model = keras.models.load_model(load_path)

for z in range(10):
    z=z+1
    
    data[:,6]=amp*z
    #normalization
    normed=norm(data)
    

    temp=pd.DataFrame(data,columns=column_names_r)
    test_predictions= model.predict(normed).flatten()
    temp['Prediction']=test_predictions
    
    if z==1:
        res=temp.copy()
    else:
        res=res.append(temp,ignore_index=True, sort=False)




amplitude=res[['Depth','Amplitude','Prediction']]


X=res['Depth'].values
Y=res['Amplitude'].values
Z=res['Prediction'].values
X=X.reshape((10, 2001))
Y=Y.reshape((10, 2001))
Z=Z.reshape((10, 2001))
plt.figure(figsize=(7,5))
plt.xlabel('Depth')
plt.ylabel('Amplitude')
plt.contourf( X[0,:],Y[:,0],Z, cmap='RdBu')
clb = plt.colorbar()
clb.ax.set_title('Hardness')
plt.show()

# %% [markdown]
# For Number of strikes vs depth

# %%
st_force=30
amp=30
num_strike=1000
max_depth=2000

data=np.zeros(((max_depth+1),7))

data[:,0]=uts
data[:,1]=ys
data[:,2]=cr
data[:,5]=st_force
data[:,6]=amp
data[:,3]=np.arange(max_depth+1)

#loaded model

model = keras.models.load_model(load_path)

for z in range(10):
    z=z+1
    
    data[:,4]=num_strike*z
    #normalization
    normed=norm(data)
    

    temp=pd.DataFrame(data,columns=column_names_r)
    test_predictions= model.predict(normed).flatten()
    temp['Prediction']=test_predictions
    
    if z==1:
        res=temp.copy()
    else:
        res=res.append(temp,ignore_index=True, sort=False)



Nums=res[['Depth','Strikes/mm2','Prediction']]


X=res['Depth'].values
Y=res['Strikes/mm2'].values
Z=res['Prediction'].values
X=X.reshape((10, 2001))
Y=Y.reshape((10, 2001))
Z=Z.reshape((10, 2001))
plt.figure(figsize=(7,5))
plt.xlabel('Depth')
plt.ylabel('Number of Strikes/mm2')
plt.contourf( X[0,:],Y[:,0],Z, cmap='RdBu')
clb = plt.colorbar()
clb.ax.set_title('Hardness')
plt.show()

# %%
st_force=30
amp=30
num_strike=3000
max_depth=2000

data=np.zeros(((max_depth+1),7))

data[:,0]=uts
data[:,1]=ys
data[:,2]=cr
data[:,5]=st_force
data[:,6]=amp
data[:,3]=np.arange(max_depth+1)

#loaded model

model = keras.models.load_model(load_path)

for z in range(10):
    z=z+1
    
    data[:,4]=num_strike*z
    #normalization
    normed=norm(data)
    

    temp=pd.DataFrame(data,columns=column_names_r)
    test_predictions= model.predict(normed).flatten()
    temp['Prediction']=test_predictions
    
    if z==1:
        res=temp.copy()
    else:
        res=res.append(temp,ignore_index=True, sort=False)



Nums=res[['Depth','Strikes/mm2','Prediction']]


X=res['Depth'].values
Y=res['Strikes/mm2'].values
Z=res['Prediction'].values
X=X.reshape((10, 2001))
Y=Y.reshape((10, 2001))
Z=Z.reshape((10, 2001))
plt.figure(figsize=(7,5))
plt.xlabel('Depth')
plt.ylabel('Number of Strikes/mm2')
plt.contourf( X[0,:],Y[:,0],Z, cmap='RdBu')
clb = plt.colorbar()
clb.ax.set_title('Hardness')
plt.show()

# %% [markdown]
# for static load vs amplitude

# %%
st_force=100
amp=10
num_strike=20000
max_depth=0

data=np.zeros(((10),7))
data[:,0]=uts
data[:,1]=ys
data[:,2]=cr
data[:,5]=np.arange(10,st_force+1,step=10)
data[:,4]=num_strike
data[:,3]=0
#loaded model


model = keras.models.load_model(load_path)

for z in range(10):
    z=z+1
    
    data[:,6]=amp*z
    #normalization
    normed=norm(data)
    

    temp=pd.DataFrame(data,columns=column_names_r)
    test_predictions= model.predict(normed).flatten()
    temp['Prediction']=test_predictions
    if z==1:
        res=temp.copy()
    else:
        res=res.append(temp,ignore_index=True, sort=False)


    
    
SvA=res[['Static Force','Amplitude','Prediction']]

X=res['Static Force'].values
Y=res['Amplitude'].values
Z=res['Prediction'].values
X=X.reshape((10, 10))
Y=Y.reshape((10, 10))
Z=Z.reshape((10, 10))
plt.figure(figsize=(7,5))
plt.xlabel('Static Force')
plt.ylabel('Amplitude')
plt.contourf( X[0,:],Y[:,0],Z, cmap='RdBu')
clb = plt.colorbar()
clb.ax.set_title('Hardness')
plt.show()

# %%
K.clear_session()

# %%
final_data=pd.concat([static,amplitude],axis=1)
final_data=pd.concat([final_data,Nums],axis=1)
final_data=pd.concat([final_data,SvA],axis=1)


num=1;
file='result-'+str(num)+'.csv'
while os.path.exists(file):
    num=num+1
    file='result-'+str(num)+'.csv'
final_data.to_csv(file)

# %% [markdown]
# # Single Predict

# %%
def sim(mat,x,y,z):   
    
        #insert parameter 
    uts,ys,hard,cr=set_mat(mat)

    st_force=x
    amp=y
    num_strike=z
    max_depth=2000


    data=np.zeros(((max_depth+1),7))

    data[:,0]=uts
    data[:,1]=ys
    data[:,2]=cr
    data[:,6]=amp
    data[:,4]=num_strike
    data[:,3]=np.arange(max_depth+1)
    data[:,5]=st_force 
        
    

    normed=norm(data)  

    temp=pd.DataFrame(data,columns=column_names_r)
    test_predictions= model.predict(normed).flatten()
    res=pd.DataFrame(data,columns=column_names_r)
    res['Predict']=test_predictions


    fig, ax = plt.subplots()
    ax.set_xlabel('Depth')
    ax.set_ylabel('Hardness')
    ax.plot(res['Depth'], res['Predict'],label='Predict')

    ax.set_xlim([0,max_depth+1])
    ax.axhline(y=0, color='k')
    # set the y-spine
    ax.grid(linestyle=':')
  
    ax.legend()



#     print('Max Compressive Stress :', np.min(res['Predict']))
#     print('Max Tensile Stress :', np.max(res['Predict']))

#     for k in range(max_depth+1):
#         if res['Predict'][k]<0:
#             temp = res['Predict'][k]
#             temp1=k
#         elif res['Predict'][k]>0:
#             break


#     print('Depth : ',res['Depth'][temp1],res['Predict'][temp1])



#     num=1;
#     file='result-'+str(num)+'.csv'
#     while os.path.exists(file):
#         num=num+1
#         file='result-'+str(num)+'.csv'


    #res.to_csv(file)

            
def sim_c(mat,x,y,z,rs_d,rs_v):   
    
        #insert parameter 
       
    
    uts,ys,hard,cr=set_mat(mat)

    st_force=x
    amp=y
    num_strike=z
    max_depth=2000


    data=np.zeros(((max_depth+1),7))

    data[:,0]=uts
    data[:,1]=ys
    data[:,2]=cr
    data[:,6]=amp
    data[:,4]=num_strike
    data[:,3]=np.arange(max_depth+1)
    data[:,5]=st_force 
        


    normed=norm(data)

    test_predictions= model.predict(normed).flatten()

    res=pd.DataFrame(data,columns=column_names_r)
    res['Predict']=test_predictions


    fig, ax = plt.subplots()
    ax.set_xlabel('Depth')
    ax.set_ylabel('Hardness')
    ax.plot(res['Depth'], res['Predict'],label='Predict')
    ax.scatter(rs_d,rs_v,label='Ex')  
    ax.set_xlim([0,max_depth+1])
   
    ax.axhline(y=0, color='k')
    # set the y-spine
    ax.grid(linestyle=':')
    #plt.ylim([-1000,1000])
    ax.legend()





#     print('Max Compressive Stress :', np.min(res['Predict']))
#     print('Max Tensile Stress :', np.max(res['Predict']))

#     for k in range(max_depth+1):
#         if res['Predict'][k]<0:
#             temp = res['Predict'][k]
#             temp1=k
#         elif res['Predict'][k]>0:
#             break


#     print('Depth : ',res['Depth'][temp1],res['Predict'][temp1])


#     num=1;
#     file='result-'+str(num)+'.csv'
#     while os.path.exists(file):
#         num=num+1
#         file='result-'+str(num)+'.csv'


    #res.to_csv(file)

# %%
sim('600',100,30,8500)

# %%
sim('600',50,30,8500)

# %%
sim('600',120,30,8500)

# %%
sim('600',120,50,20000)

# %%
sim('690',120,50,20000)

# %%
sim('718',50,30,5000)

# %%
sim('690',120,30,8500)

# %%
sim('718',50,50,8500)

# %%
sim('718',80,30,8500)

# %%
sim('718',50,50,50000)

# %%
sim('718p',80,60,10000)

# %%
sim('718',80,10,20000)

# %%
sim('690',50,50,8571)

# %%
sim('690',50,50,40000)

# %%
rs_v=[-1562.31245,-1532.840686,-1540.24401,-1451.828716,-1300.760066,
      -1138.649029,-928.6667891,-807.1270609,-685.5846109,-232.5229142,
      161.5598696,585.130749,607.0086622,473.8468029,407.2767605,311.2022918]
rs_d=[0,10,20,30,40,50,80,100,130,200,300,350,450,600,675,750]
sim_c('718',70,30,5714,rs_d,rs_v)

# %%
rs_690=[-965,-741.8372491,-554.0228053,-412.0354238,-247.1411837,-125.5339892,-121.0811753,-19.85083147,119.5798519,134.2260956,176.8859217]
depth_690=[0,25,50,75,100,125,150,175,200,225,250]
sim_c('690',50,50,8571,depth_690,rs_690)
